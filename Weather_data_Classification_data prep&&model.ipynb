# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # plot
# import seaborn as sns

# %%
# Read the dataset
df = pd.read_csv("weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# Initial exploration
df.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        143975.0    12.194034   6.398495   -8.5     7.6    12.0
# MaxTemp        144199.0    23.221348   7.119049   -4.8    17.9    22.6
# Rainfall       142199.0     2.360918   8.478060    0.0     0.0     0.0
# Evaporation     82670.0     5.468232   4.193704    0.0     2.6     4.8
# Sunshine        75625.0     7.611178   3.785483    0.0     4.8     8.4
# WindGustSpeed  135197.0    40.035230  13.607062    6.0    31.0    39.0
# WindSpeed9am   143693.0    14.043426   8.915375    0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.662657   8.809800    0.0    13.0    19.0
# Humidity9am    142806.0    68.880831  19.029164    0.0    57.0    70.0
# Humidity3pm    140953.0    51.539116  20.795902    0.0    37.0    52.0
# Pressure9am    130395.0  1017.649940   7.106530  980.5  1012.9  1017.6
# Pressure3pm    130432.0  1015.255889   7.037414  977.1  1010.4  1015.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
pd.options.display.max_rows=None
pd.options.display.max_columns=None
dfXX=pd.DataFrame(None,index=[df.columns])
dfXX['dtype'] = dict(df.dtypes).values()
dfXX.T
# Out:
#          Date Location  MinTemp  MaxTemp Rainfall Evaporation Sunshine  \
# dtype  object   object  float64  float64  float64     float64  float64
#
#       WindGustDir WindGustSpeed WindDir9am WindDir3pm WindSpeed9am  \
# dtype      object       float64     object     object      float64
#
#       WindSpeed3pm Humidity9am Humidity3pm Pressure9am Pressure3pm Cloud9am  \
# dtype      float64     float64     float64     float64     float64  float64
#
#       Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# dtype  float64  float64  float64    object       object

# %%
# Calculate the percentages of missing values
null_percentages = df.isnull().sum() / len(df)
null_percentages
# Out:
# Date             0.000000
# Location         0.000000
# MinTemp          0.010209
# MaxTemp          0.008669
# Rainfall         0.022419
# Evaporation      0.431665
# Sunshine         0.480098
# WindGustDir      0.070989
# WindGustSpeed    0.070555
# WindDir9am       0.072639
# WindDir3pm       0.029066
# WindSpeed9am     0.012148
# WindSpeed3pm     0.021050
# Humidity9am      0.018246
# Humidity3pm      0.030984
# Pressure9am      0.103568
# Pressure3pm      0.103314
# Cloud9am         0.384216
# Cloud3pm         0.408071
# Temp9am          0.012148
# Temp3pm          0.024811
# RainToday        0.022419
# RainTomorrow     0.022460
# dtype: float64

# %%
# Get rid of the columns which have more than 35% missing data
null_features = null_percentages[null_percentages > 0.35].index
df_dropped = df.drop(null_features, axis = 1)
df_dropped.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %%
# Get rid of the pointless column
df_dropped = df_dropped.drop(['Date'], axis = 1)
df_dropped.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0   Albury     13.4     22.9       0.6           W           44.0          W
# 1   Albury      7.4     25.1       0.0         WNW           44.0        NNW
# 2   Albury     12.9     25.7       0.0         WSW           46.0          W
# 3   Albury      9.2     28.0       0.0          NE           24.0         SE
# 4   Albury     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# ...

# %%
# Get rid of the null rows
df_dropped = df_dropped.dropna()
df_dropped.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0   Albury     13.4     22.9       0.6           W           44.0          W
# 1   Albury      7.4     25.1       0.0         WNW           44.0        NNW
# 2   Albury     12.9     25.7       0.0         WSW           46.0          W
# 3   Albury      9.2     28.0       0.0          NE           24.0         SE
# 4   Albury     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# ...

# %%
# Recheck the number of count and null for 'df_dropped'
count_num = pd.DataFrame(df_dropped.count())
null_num = pd.DataFrame(df_dropped.isnull().sum())
df_dropped_describe = pd.concat([count_num, null_num], axis = 1)
df_dropped_describe.columns = ['count', 'null']
df_dropped_describe['dtype'] = dict(df_dropped.dtypes).values()
df_dropped_describe
# Out:
#                 count  null    dtype
# Location       112925     0   object
# MinTemp        112925     0  float64
# MaxTemp        112925     0  float64
# Rainfall       112925     0  float64
# WindGustDir    112925     0   object
# WindGustSpeed  112925     0  float64
# WindDir9am     112925     0   object
# WindDir3pm     112925     0   object
# WindSpeed9am   112925     0  float64
# WindSpeed3pm   112925     0  float64
# Humidity9am    112925     0  float64
# Humidity3pm    112925     0  float64
# Pressure9am    112925     0  float64
# Pressure3pm    112925     0  float64
# Temp9am        112925     0  float64
# Temp3pm        112925     0  float64
# RainToday      112925     0   object
# RainTomorrow   112925     0   object

# %%
# Group the data by numerical and categorical variables
categorical_var = df_dropped[list(df_dropped_describe.loc[df_dropped_describe['dtype']=='object'].index)]
numerical_var = df_dropped[list(df_dropped_describe.loc[df_dropped_describe['dtype']=='float64'].index)]

# %%
# Recheck the number of count for 'numerical_var'
count_num_1 = pd.DataFrame(numerical_var.count())
count_num_1.columns = ['count']
count_num_1['dtype'] = dict(numerical_var.dtypes).values()
count_num_1
# Out:
#                 count    dtype
# MinTemp        112925  float64
# MaxTemp        112925  float64
# Rainfall       112925  float64
# WindGustSpeed  112925  float64
# WindSpeed9am   112925  float64
# WindSpeed3pm   112925  float64
# Humidity9am    112925  float64
# Humidity3pm    112925  float64
# Pressure9am    112925  float64
# Pressure3pm    112925  float64
# Temp9am        112925  float64
# Temp3pm        112925  float64

# %%
# Recheck the number of count for 'categorical_var'
count_num_1 = pd.DataFrame(categorical_var.count())
count_num_1.columns = ['count']
count_num_1['dtype'] = dict(categorical_var.dtypes).values()
count_num_1
# Out:
#                count   dtype
# Location      112925  object
# WindGustDir   112925  object
# WindDir9am    112925  object
# WindDir3pm    112925  object
# RainToday     112925  object
# RainTomorrow  112925  object

# %%
# Check the numerical variables
numerical_var.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0     13.4     22.9       0.6           44.0          20.0          24.0
# 1      7.4     25.1       0.0           44.0           4.0          22.0
# 2     12.9     25.7       0.0           46.0          19.0          26.0
# 3      9.2     28.0       0.0           24.0          11.0           9.0
# 4     17.5     32.3       1.0           41.0           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm
# 0         71.0         22.0       1007.7       1007.1     16.9     21.8
# 1         44.0         25.0       1010.6       1007.8     17.2     24.3
# 2         38.0         30.0       1007.6       1008.7     21.0     23.2
# 3         45.0         16.0       1017.6       1012.8     18.1     26.5
# 4         82.0         33.0       1010.8       1006.0     17.8     29.7

# %%
# Check the categorical variables
categorical_var.head()
# Out:
#   Location WindGustDir WindDir9am WindDir3pm RainToday RainTomorrow
# 0   Albury           W          W        WNW        No           No
# 1   Albury         WNW        NNW        WSW        No           No
# 2   Albury         WSW          W        WSW        No           No
# 3   Albury          NE         SE          E        No           No
# 4   Albury           W        ENE         NW        No           No

# %%
# Scale the numerical variables
from sklearn.preprocessing import StandardScaler
numerical_var = StandardScaler().fit_transform(numerical_var)
numerical_var.shape
# Out:
# (112925, 12)

# %%
# Transform the categorical variables into numbers
from sklearn.preprocessing import LabelEncoder
Arrays = []
for col in list(categorical_var):
    Encoder = LabelEncoder()
    Encoder.fit(categorical_var[col])
    Arrays.append(Encoder.transform(categorical_var[col]))
categorical_var = Arrays[0]
for i in range(len(Arrays)-1):
    categorical_var = np.vstack((categorical_var, Arrays[i+1]))
categorical_var = categorical_var.T
categorical_var.shape
# Out:
# (112925, 6)

# %%
# Regroup the data by explanatory variables and response variable
X_all = np.hstack((categorical_var[:,0:-1],numerical_var))
y = categorical_var[:,-1]

# %%
X_all.shape
# Out:
# (112925, 17)

# %%
y.shape
# Out:
# (112925,)

# %%
# Check the correlation of columns
c = pd.DataFrame(X_all, columns = list(df_dropped)[0:-1]).corr()
c
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  WindGustDir  \
# Location       1.000000  0.032909 -0.019989  0.022470    -0.000757
# MinTemp        0.032909  1.000000  0.403542  0.601054     0.137906
# MaxTemp       -0.019989  0.403542  1.000000  0.305955     0.174094
# Rainfall       0.022470  0.601054  0.305955  1.000000     0.126229
# WindGustDir   -0.000757  0.137906  0.174094  0.126229     1.000000
# WindGustSpeed -0.009515 -0.166074 -0.066436 -0.168547     0.044605
# WindDir9am    -0.050913 -0.224415 -0.248406 -0.178135    -0.242983
# WindDir3pm    -0.004546  0.044939  0.084177  0.046577     0.497554
# WindSpeed9am   0.085213  0.134843  0.025126  0.134630     0.154943
# WindSpeed3pm   0.086070  0.023290  0.010127  0.045438     0.099773
# Humidity9am    0.084724  0.099502  0.077561  0.092563     0.087702
# Humidity3pm    0.012638  0.071479  0.153097  0.029611     0.378306
# Pressure9am    0.043686  0.049654  0.174934 -0.017852     0.386619
# ...

# %%
# Find the pairs of columns which have a strong correlation (more than 0.95) with each other
row_num_and_col_num = []
row_name_and_col_name = []
c = np.array(c)
for i in range(len(c)):
    for j in range(i+1, len(c)):
        if abs(c[i,j]) >= 0.95:
            row_num_and_col_num.append((i,j))
            row_name_and_col_name.append((list(df_dropped)[i],list(df_dropped)[j]))
row_name_and_col_name
# Out:
# [('WindDir9am', 'RainToday'), ('Pressure3pm', 'Temp9am')]

# %%
# Get rid of the columns which have a strong correlation with others
cols = list(range(0, row_num_and_col_num[0][0])) + list(range((row_num_and_col_num[0][0]+1), row_num_and_col_num[1][1])) + list(range((row_num_and_col_num[1][1]+1), len(c)))
X = X_all[:,cols]
X.shape
# Out:
# (112925, 15)

# %% [markdown]
# # Models

# %%
# Split the dataset to train set and test set
from sklearn.model_selection import train_test_split
train, test, train_labels, test_labels = train_test_split(X,
                                                          y,
                                                          test_size=0.33,
                                                          random_state=42)

# %%
# import all the models
from sklearn.naive_bayes import GaussianNB
from sklearn import neighbors
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
methods = [GaussianNB(), neighbors.KNeighborsClassifier(), tree.DecisionTreeClassifier(criterion='gini'), RandomForestClassifier(), GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)]
methods_names = ['Naive-Bayes classifier', 'k-nearest neighbors algorithm', 'decision trees', 'random forests', 'GBDT']

# run all the models in a loop
for i in range(len(methods)):
    
    # model initialization
    model = methods[i]

    # model fitting & training
    model.fit(train, train_labels)

    # model prediction
    preds = model.predict(test)

    # model evaluation
    print('This is the result of ', methods_names[i], ':', sep="")
    print('The accuracy rate of is ', 100 * accuracy_score(test_labels, preds), '%!', sep="")
    print('The precision rate of is ', 100 * precision_score(test_labels, preds), '%!', sep="")
    print('The recall rate of is ', 100 * recall_score(test_labels, preds), '%!', sep="")
    print('The f1 score of is ', 100 * f1_score(test_labels, preds), '%!', sep="")
    print('----------------------------------------------------------------------')
# Out:
# This is the result of Naive-Bayes classifier:
# The accuracy rate of is 80.76262544947137%!
# The precision rate of is 58.189366546136334%!
# The recall rate of is 51.77550047664442%!
# The f1 score of is 54.795384324358395%!
# ----------------------------------------------------------------------
# This is the result of k-nearest neighbors algorithm:
# The accuracy rate of is 82.67053077872592%!
# The precision rate of is 69.4410936871733%!
# The recall rate of is 41.158245948522406%!
# The f1 score of is 51.683375729462824%!
# ----------------------------------------------------------------------
# This is the result of decision trees:
# The accuracy rate of is 78.52466054848925%!
# The precision rate of is 52.28420434527305%!
# The recall rate of is 53.05052430886559%!
# The f1 score of is 52.664576802507845%!
# ----------------------------------------------------------------------
# This is the result of random forests:
# The accuracy rate of is 85.51763001127033%!
# ...
